# %% [markdown]
# Student Mental Health data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Student Mental Health Survey.csv')
print(df.head())
# Out:
#           Timestamp         DOB  Gender  \
# 0  3/4/2025 8:10:55  10/24/2005  Female
# 1  3/4/2025 8:25:07   1/11/2006  Female
# 2  3/4/2025 9:26:23  10/29/2005  Female
# 3  3/4/2025 9:31:11   4/18/2005  Female
# 4  3/4/2025 9:47:36    6/4/2006  Female
#
#    How would you describe your general mood this past week  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
# 3                                                  2
# 4                                                  3
#
#   How often do you feel overwhelmed by daily tasks ( studies, etc)  \
# 0                                         Frequently
# 1                                       Occasionally
# 2                                       Occasionally
# 3                                         Frequently
# 4                                         Frequently
#
#        What motivates you get through the day  \
# ...

# %%
print(df.isnull().sum())
df.dropna(axis=1)
# Out:
# Timestamp                                                                                                           0
# DOB                                                                                                                 0
# Gender                                                                                                              0
# How would you describe your general mood this past week                                                             0
# How often do you feel overwhelmed by daily tasks ( studies, etc)                                                    0
# What motivates you get through the day                                                                              0
# Describe your energy level throughout the day [Morning ]                                                            0
# Describe your energy level throughout the day [After]                                                               0
# ...

# %%
print(df.describe())
# Out:
#        How would you describe your general mood this past week  \
# count                                          90.000000
# mean                                            3.077778
# std                                             1.019228
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             4.000000
# max                                             5.000000
#
#        How difficult is it for you to reduce your screen time when you want to?
# count                                          90.000000
# mean                                            3.000000
# std                                             1.059998
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# ...

# %%
mood_counts = df['How would you describe your general mood this past week'].value_counts().sort_index()
mood_counts.plot(kind='bar', color='skyblue')
plt.title('Distribution of General Mood')
plt.xlabel('Mood (1-5)')
plt.ylabel('Number of Students')
plt.show()

# %%
overwhelmed_counts = df['How often do you feel overwhelmed by daily tasks ( studies, etc)'].value_counts()
overwhelmed_counts.plot(kind='bar', color='lightcoral')
plt.title('Frequency of Feeling Overwhelmed by Daily Tasks')
plt.xlabel('Frequency')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.show()

# %%
social_media_counts = df['On average, how much time do you spend daily on social media (Instagram, YouTube, etc.)?'].value_counts()
social_media_counts.plot(kind='bar', color='lightgreen')
plt.title('Time Spent Daily on Social Media')
plt.xlabel('Time Spent')
plt.ylabel('Number of Students')
plt.xticks(rotation=45)
plt.show()

# %%
cross_tab = pd.crosstab(df['How would you describe your general mood this past week'], df['On average, how much time do you spend daily on social media (Instagram, YouTube, etc.)?'])
cross_tab.plot(kind='bar', stacked=True)
plt.title('General Mood vs. Social Media Usage')
plt.xlabel('General Mood')
plt.ylabel('Number of Students')
plt.xticks(rotation=0)
plt.legend(title='Social Media Usage')
plt.show()
